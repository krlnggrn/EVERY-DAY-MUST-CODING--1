# %% [markdown]
# <a href="https://colab.research.google.com/github/krlnggrn/EVERY-DAY-MUST-CODING--1/blob/main/EVERY_DAY_MUST_CODING_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Detai: di OneNote > Python > pandas

# %% [markdown]
# # Simple PANDAS

# %% [markdown]
# Simple PANDAS from a dictionary

# %%
#PANDAS with series : kolom yg ada index nya dan kita
#bisa mengontrol index ini
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#with index argument, can make a labels
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
calories = {'day1': 420, 'day2' : 380, 'day3' : 390}
myvar = pd.Series(calories, index = ['day1', 'day2'])
myvar
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# DataFrame

# %%
#Create a DataFrame from two Series:
import pandas as pd
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#apa bedanya???
import pandas as pd
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
myvar
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#load data into a DataFrame object:
dc = pd.DataFrame(data)

# %% [markdown]
# **Locate Row (df.loc[])**

# %%
#Locate Row (df.loc[]) . pandas use the loc attribute to return one or more specified row(s)
dc.loc[0]
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#Note: When using [], the result is a Pandas DataFrame.
dc.loc[[0]]
# Out:
#    calories  duration
# 0       420        50

# %%
#named indexes
dc = pd.DataFrame(data, index = ["day1", "day2", "day3"])

dc
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
# Use the named index in the loc attribute to return the specified row(s)
print(dc.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# ## CELANING DATA

# %% [markdown]
# LOAD FILES INTO A DATAFRAME

# %%
df = pd.read_csv('/content/drive/MyDrive/EVERYDAY MUST CODING/dirtydata.csv')
df.head
# Out:
# <bound method NDFrame.head of     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#Notice in the result that some rows have been removed (row 18, 22 and 28).

#These rows had cells with empty values.
new_df = df1.dropna()
new_df

#By default, the dropna() method returns a new DataFrame, and will not change the original.
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#if want to change the original dataframe, use the inplace=True argument

new_df.dropna(inplace = True)
new_df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# Replace empty value with fillna()

# %%
df.fillna(130, inplace = True)

df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#Replace NULL values in the "Calories" columns with the number 130:

df["Calories"].fillna(130, inplace = True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   32.000000
# mean    68.437500  103.500000  128.500000  293.762500
# std     70.039591    7.832933   12.998759   76.947937
# min     30.000000   90.000000  101.000000  130.000000
# 25%     60.000000  100.000000  120.000000  249.000000
# 50%     60.000000  102.500000  127.500000  282.200000
# 75%     60.000000  106.500000  132.250000  341.325000
# max    450.000000  130.000000  175.000000  479.000000

# %%
x = df["Calories"].mean()
x
# Out:
# 293.76249999999993

# %%
#replace using mean, median, mode
x = df["Calories"].mean()
df["Calories"].fillna(x, inplace = True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#Calculate the MEDIAN, and replace any empty values with it:

x = df["Calories"].median()
df["Calories"].fillna(x, inplace = True)

# %%
#Calculate the MODE, and replace any empty values with it:

x = df["Calories"].mode()[0]
df["Calories"].fillna(x, inplace = True)

# %% [markdown]
# Data wrong format

# %%
#data of wrong format, lets change date into datetime and should be a string ''
df['Date'] = pd.to_datetime(df['Date'])
print(df.to_string())
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# Removing Rows

# %%
#Remove rows with a NULL/NaT value in the "Date" column:
df.dropna(subset=['Date'], inplace = True)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
#isi NaN calories dengan MODE
x = df['Calories'].mode()[0]
df['Calories'].fillna(x, inplace = True)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# Wrong data, and to replacing values

# %%
df.loc[7, 'Duration'] = 45
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df.loc[18, 'Duration'] = 350
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
#Delete rows where "Duration" is higher than 60:

for x in df.index:
  if df.loc[x, 'Duration'] > 120:
    df.drop(x, inplace = True)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# Discovering duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 19    False
# 20    False
# 21    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
#removing duplicates , row 12
df.drop_duplicates(inplace = True)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %% [markdown]
# ## DATA CORRELATIONS

# %% [markdown]
# finding relationship

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.185407 -0.386810  0.347552
# Pulse    -0.185407  1.000000  0.198951  0.503531
# Maxpulse -0.386810  0.198951  1.000000  0.337536
# Calories  0.347552  0.503531  0.337536  1.000000

# %% [markdown]
# ## PLOTTING
# to create diagrams. we can use pyplot, a submodule of the matplotlib library to visualize the diagram on the screen

# %%
import matplotlib.pyplot as plt

dd = pd.read_csv('/content/drive/MyDrive/EVERYDAY MUST CODING/data.csv')

# %%
dd
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# **NOTE: ** kalo mau buat diagram, scatter, etc. jauhi dari data **DATETIME** jangan smpe ada!

# %%
dd.plot()
plt.show()

# %%
dd.plot(kind = 'scatter',x = 'Duration',y = 'Calories')
plt.show()

# %% [markdown]
# Remember: In the previous example, we learned that the correlation between "Duration" and "Calories" was 0.922721, and we conluded with the fact that higher duration means more calories burned.
#
# By looking at the scatterplot, I will agree.
#
# Let's create another scatterplot, where there is a bad relationship between the columns, like "Duration" and "Maxpulse", with the correlation 0.009403:

# %%
dd.plot(kind = 'scatter',x = 'Duration',y = 'Maxpulse')
plt.show()

# %%
dd['Duration'].plot(kind = 'hist')

# %% [markdown]
# Note: The histogram tells us that there were over 100 workouts that lasted between 50 and 60 minutes.

# %% [markdown]
# # MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
matplotlib.__version__
# Out:
# '3.2.2'

# %% [markdown]
# PYPLOT

# %%
# draw a line in ad diagram from position (0,0) to position (7,250)
xpoints = np.array([0, 7])
ypoints = np.array([0, 250])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Plotting x and y points

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Plotting without line

# %%
xpoints = np.array([1,8])
ypoints = np.array([3,10])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# Multiple Points

# %%
xpoints = np.array([1,3,6,8])
ypoints = np.array([3,8,1,10])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Default X=Points
# If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3, (etc. depending on the length of the y-points.
# The x-points in the example above is [0, 1, 2, 3, 4, 5].

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# Makers

# %%
ypoints = np.array([3,8,1,10,5,7])
plt.plot(ypoints, marker = 'P')
plt.show()

# %% [markdown]
# Format strings fmt

# %%
ypoints = np.array([3,8,2,10])
plt.plot(ypoints, 'o:r')
plt.show()

# %%
#set the size of the markers to 15
ypoints = np.array([3,8,2,10])
plt.plot(ypoints, marker='o', ms=20)
plt.show()

# %%
#see the EDGE color to red
ypoints = np.array([3,8,2,10])
plt.plot(ypoints, marker='o', ms=20, mec='r')
plt.show()

# %%
#face color to red
ypoints = np.array([3,8,2,10])
plt.plot(ypoints, marker='o', ms=20, mfc='r')
plt.show()

# %% [markdown]
# ##Linestyle

# %%
#dotted line
ypoints = np.array([3,8,1,10])
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
#Use a dashed line:
plt.plot(ypoints, linestyle = 'dashed')

# %%
#color
plt.plot(ypoints, color = 'r')
plt.show()

# %%
#Plot with a 20.5pt wide line:
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %%
#Multiple lines
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# ## Labels and Title

# %%
#Add labels to the x- and y-axis:
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.xlabel('Average Pulse')
plt.ylabel('Calorie Burnage')
plt.show()

# %%
# Add a plot title and labels for the x- and y-axis:

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
#Set font properties for the title and labels:
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.plot(x, y)
plt.show()

# %%
#position the title to the left:
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("Sports Watch Data", fontdict = font1, loc = 'left')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Grid Lines

# %%
#Gridlines
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("Sports Watch Data", fontdict = font1, loc = 'left')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.plot(x, y)
plt.grid()
plt.show()

# %%
#display only grid lines for the x-axis
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
plt.grid(axis = 'x')
plt.show()

# %%
#display only grid lines for the y-axis
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
plt.grid(axis = 'y')
plt.show()

# %%
#set the line properties of the grid (gridnya yg putus2 dan hijau)
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# ## subplot

# %%
#multiple plots
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
#draw 6 plots
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#title
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title('SALES')

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title('INCOME')

plt.show()

# %%
#super title
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title('SALES')

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title('INCOME')
plt.suptitle('MY SHOP')

plt.show()

# %% [markdown]
# ## Scatter

# %%
#scatter plot
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# The observation in the example above is the result of 13 cars passing by.
#
# The X-axis shows how old the car is.
#
# The Y-axis shows the speed of the car when it passes.
#
# Are there any relationships between the observations?
#
# It seems that the newer the car, the faster it drives, but that could be a coincidence, after all we only registered 13 cars.

# %%
#Compare plots
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# Note: The two plots are plotted with two different colors, by default blue and orange, you will learn how to change colors later in this chapter.
#
# By comparing the two plots, I think it is safe to say that they both gives us the same conclusion: the newer the car, the faster it drives.

# %%
#colos
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
#color array and specify a colormap in the scatter plot
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
#include colormap
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.show()

# %%
#size
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
#alpha
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
#combine color size alpha
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# ## Grafik Bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# he bar() function takes arguments that describes the layout of the bars.
#
# The categories and their values represented by the first and second argument as arrays.
#
# Example
# x = ["APPLES", "BANANAS"]
# y = [400, 350]
# plt.bar(x, y)

# %%
#horizon
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
#add color
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = 'green')
plt.show()

# %%
#bar width / pake ukuran
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
#bar height
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# ## histogram

# %%
x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [180.2103998  170.52082812 155.36818894 168.1068183  163.35886434
#  156.1073705  169.71040658 175.02943438 171.59653166 156.72861077
#  169.71036549 158.11004759 170.44752974 169.7292309  171.6196226
#  183.37082494 170.23783009 165.50189516 193.22861442 164.31329839
#  176.04614979 162.96144345 176.92967722 155.55581767 171.76068541
#  173.86783268 163.36340814 168.09910536 165.01442373 171.09192588
#  175.98995228 184.01473962 165.6312938  169.80789972 176.18896964
#  160.16741036 175.64751443 180.23991831 171.2167185  147.66263142
#  172.07209773 168.77376768 158.33456231 173.18581981 191.71422334
#  168.15591893 177.48921119 181.3170669  166.17599907 167.40871948
#  171.1741426  172.23097983 159.31774673 152.7901339  178.99465694
#  186.83142593 165.39758354 163.18888003 186.51777427 162.49134705
#  175.20431562 178.45712604 163.76336708 180.96736009 168.7073814
#  153.6247847  164.66964716 170.29091337 192.80081538 177.05046292
# ...

# %%
#The hist() function will read the array and produce a histogram:
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %%
#normal distribution
import numpy
x = numpy.random.normal(5.0, 1.0, 100000)
plt.hist(x, 100)
plt.show()

# %% [markdown]
# fungsi numpy:
# Membuat vektor, matriks, dan memilih elemen.
# Mencari nilai max dan min, dan menghitung nilai rata-rata, varian, dan standar deviasi.
# Melakukan Transpose dan Menghitung Determinan.

# %% [markdown]
# ## Pie Charts

# %%
y = np.array([35, 25, 25, 15])
plt.pie(y)
plt.show()

# %%
#add labels
mylabels = ['Apples', 'Bananas', 'Cherries', 'Dates']
plt.pie(y, labels = mylabels)
plt.show()

# %%
#with wedge at 90 degrees
mylabels = ['Apples', 'Bananas', 'Cherries', 'Dates']
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
#explod
mylabels = ['Apples', 'Bananas', 'Cherries', 'Dates']
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
#shadow
mylabels = ['Apples', 'Bananas', 'Cherries', 'Dates']
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# colors

# %%
mylabels = ['Apples', 'Bananas', 'Cherries', 'Dates']
mycolors = ['green', 'hotpink', 'b', '#4CAF50']
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# Legend

# %%
mylabels = ['Apples', 'Bananas', 'Cherries', 'Dates']
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
#legend with header
mylabels = ['Apples', 'Bananas', 'Cherries', 'Dates']
plt.pie(y, labels = mylabels)
plt.legend(title = 'Four Fruits')
plt.show()
